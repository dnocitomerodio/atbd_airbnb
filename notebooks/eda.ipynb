# %%
import pandas as pd

df = pd.read_csv('/app/data/...algún_archivo.csv')
df.head()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("AirbnbETL") \
    .master("local[*]") \
    .getOrCreate()

df = spark.read.csv("/app/data/*.csv", header=True, inferSchema=True)
df.show()
