# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("AirbnbEDA") \
    .master("yarn") \
    .getOrCreate()

df_raw = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("multiLine", True) \
    .csv("hdfs://localhost:9000/data/airbnb/Listings.csv")

print(f"Filas totales: {df_raw.count()}")

df_raw.select("listing_id", "amenities", "price", "minimum_nights").show(5)
# Out:
# 25/11/26 22:26:06 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# Filas totales: 279712
# +----------+--------------------+-----+--------------+
# |listing_id|           amenities|price|minimum_nights|
# +----------+--------------------+-----+--------------+
# |    281420|["Heating", "Kitc...|   53|             2|
# |   3705183|["Shampoo", "Heat...|  120|             2|
# |   4082273|["Heating", "TV",...|   89|             2|
# |   4797344|["Heating", "TV",...|   58|             2|
# |   4823489|["Heating", "TV",...|   60|             2|
# +----------+--------------------+-----+--------------+
# only showing top 5 rows
